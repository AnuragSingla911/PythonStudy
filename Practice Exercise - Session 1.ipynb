# %%
#Import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### I - Virat Kohli Dataset

# %%
df = pd.read_csv("virat.csv")

# %%
df.head()
df['Date'] = pd.to_datetime(df['Start Date'])
df['Year'] = df['Date'].dt.year
df.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       Date  Year
# 0       Dambulla  18-Aug-08 2008-08-18  2008
# 1       Dambulla  20-Aug-08 2008-08-20  2008
# 2  Colombo (RPS)  24-Aug-08 2008-08-24  2008
# 3  Colombo (RPS)  27-Aug-08 2008-08-27  2008
# 4  Colombo (RPS)  29-Aug-08 2008-08-29  2008

# %% [markdown]
# #### Spread in Runs
# Question 1: Analyse the spread of Runs scored by Virat in all his matches and report the difference between the scores at the 50th percentile and the 25th percentile respectively.
#
#     a)16.5
#     b)22.5
#     c)26.5
#     d)32.5

# %%
## Your code here
# df.Runs = df.Runs.str.rstrip('*').astype(int)
# df.Inns = df.Inns.astype('int')
df.Runs.describe()
df.Mins = df.Mins.str.rstrip('-')

# %% [markdown]
# #### Box Plots
#
# Question 2: Plot a Box Plot to analyse the spread of Runs that Virat has scored. The upper fence in the box plot lies in which interval?
#
#     a)100-120
#     b)120-140
#     c)140-160
#     d)160-180

# %%
#Your code here
plt.plot(df.Year, df.Inns)

# %%
plt.plot(df.Year, df.Runs)

# %% [markdown]
# #### False Statement
#
# Q3:Consider the following statements and choose the correct option
#
#      I - Virat has played the maximum number of matches in 2011
#      II - Virat has the highest run average in the year 2017
#      III - Virat has the maximum score in a single match and the highest run average in the year 2016.
#
# Which of the above statements is/are false?
#
#     a)I and II
#     b)I and III
#     c)II
#     d)III

# %%
## Your code here
df1 = df.groupby('Year').max()
df1
# Out:
#       Runs Mins   BF  4s  6s     SR  Pos Dismissal  Inns      Opposition  \
# Year
# 2008    54   87   67   7   1  81.81    2   run out     2     v Sri Lanka
# 2009   107   93  114  11   1  93.85    7   not out     2     v Sri Lanka
# 2010   118   98  121  11   2  97.52    5   run out     2      v Zimbabwe
# 2011   117   99  123  16   2  95.12    7   stumped     2   v West Indies
# 2012   128    9  119  12   1   93.8    4   not out     2     v Sri Lanka
# 2013   115   86  108  18   7     99    3   run out     2      v Zimbabwe
# 2014   139    9  126  16   3  86.88    4   run out     2   v West Indies
# 2015   138    9  140   6   5  98.57    4   run out     2  v South Africa
# 2016   154   84  134  16   2  93.81    3   run out     2   v New Zealand
# 2017   122   81  105   8   5   87.3    3    caught     2       v England
#
#              Ground Start Date       Date
# Year
# 2008       Dambulla  29-Aug-08 2008-08-29
# 2009       Vadodara  25-Oct-09 2009-12-24
# ...

# %% [markdown]
# #### Maximum Frequency
#
# Q4:Plot a histogram for the Mins column with 15 bins. Among the three ranges mentioned below, which one has the highest frequency?
#
# A - [54.6,68)
#
# B - [68,81.4)
#
# C - [121.6,135)
#
#     a)A - [54.6,68)
#     b)B - [68,81.4)
#     c)C - [121.6,135)
#     d)All the bin ranges have the same frequency

# %%
#Your code here
df.Mins.value_counts()
plt.figure(figsize=(18, 10)) 

plt.hist(df.Mins, bins=[0, 54.6, 68, 81.4, 121.6, 121.6, 135])
plt.xticks(rotation=90)

plt.show()
